# %% [markdown]
# # Команда "Пандури, чонгури и дудук"

# %% [markdown]
# ## Обзор логики кода
#
# Код представляет собой приложение для поиска оптимальных маршрутов между городами с использованием данных от **Яндекс.расписаний** и **Aviasales**. он получает, обрабатывает и кэширует информацию о станциях, запрашивает маршруты через api, строит граф маршрутов, а затем находит и выводит оптимальные варианты. ниже — подробное описание работы кода;
#
# ---
#
# ### 1. Настройка логирования и констант
#
# - **Логирование:**
#   - с помощью `logging.basicConfig` задаётся формат логов и уровень логирования (`WARNING`), что означает вывод предупреждений и ошибок;
#   - создаётся логгер с именем `"RouteSystem"`, который используется для вывода информационных сообщений, предупреждений и ошибок.
#
# - **Константы:**
#   - определены пути к кэшу (файлы `stations_list.json` и `stations_list.csv`);
#   - заданы api-ключи и url для доступа к api яндекс.расписаний и aviasales;
#   - установлен файл для сохранения выбранных транспортных узлов (`selected_nodes.json`);
#   - определено минимальное время пересадки (`MIN_TRANSFER_TIME`);
#   - задан словарь для сопоставления кодов яндекс с iata (например, `"s9600370": "SVO", "s9600363": "VKO"`).
#
# ---
#
# ### 2. Получение и обработка данных станций
#
# - Получение данных:
#   - функция `fetch_stations_list_from_api` отправляет запрос к api яндекс.расписаний, получает json со списком станций и возвращает его.
#
# - Преобразование в dataframe:
#   - функция `stations_to_dataframe` проходит по структуре json (страны → регионы → населённые пункты → станции), добавляет поля с названием населённого пункта, региона и страны, нормализует данные и фильтрует их по наличию слова «россия».
#
# - Кэширование:
#   - функция `load_stations_dataframe` проверяет наличие локального кэша (csv и json) и, если файлы существуют, загружает данные из них, иначе запрашивает данные через api, сохраняет их и преобразует в dataframe;
#   - аналогичный процесс используется в функции `load_settlements_dataframe` для данных о населённых пунктах.
#
# ---
#
# ### 3. Выбор транспортного узла для города
#
# - Фильтрация узлов:
#   - функция `filter_airports_and_train_stations` отбирает записи, соответствующие аэропортам и железнодорожным станциям, исключая записи типа «settlement» и содержащие нежелательные строки.
#
# - Интерактивный выбор:
#   - функция `choose_station_interactive` выводит варианты транспортных узлов для города и запрашивает у пользователя выбор, если вариантов несколько, иначе выбирает единственный найденный вариант.
#
# - Автоматический выбор:
#   - если город не является крупным (Москва или Санкт-петербург), используется автоматический подбор кодов через функции `get_all_city_codes_automatic` и `update_node_code`;
#   - функция `select_transport_node` объединяет интерактивный и автоматический подходы в зависимости от города.
#
# ---
#
# ### 4. Ввод параметров маршрута
#
# - Сбор информации от пользователя:
#   - функция `input_route_parameters` запрашивает город отправления, город прибытия, дату путешествия (формат yyyy-mm-dd) и информацию о необходимости остановки в промежуточном городе (с указанием количества суток);
#   - производится проверка корректности введённых данных (например, дата не должна быть в прошлом).
#
# ---
#
# ### 5. Запросы маршрутов через API
#
# - Запросы к Яндекс.Расписаниям:
#   - функция `get_route_options` формирует параметры запроса (транспортные типы, количество пересадок и пр.) и отправляет запрос к api, получая данные о сегментах маршрутов;
#   - при наличии промежуточного узла запрос выполняется в два этапа: от отправления до промежуточного города и от промежуточного города до пункта прибытия с учётом дней остановки.
#
# - Запросы к Aviasales:
#   - функция `get_aviasales_routes` запрашивает данные о авиа-рейсах между указанными городами, извлекает цену, время отправления и прибытия, а также рассчитывает длительность пути.
#
# - Сохранение данных:
#   - функции `save_route_options` и `save_aviasales_route_options` сохраняют полученные данные в форматах json и csv для дальнейшего анализа.
#
# ---
#
# ### 6. Построение графа маршрутов
#
# - Объединение данных:
#   - функция `combine_route_data` объединяет сегменты маршрутов из разных источников (яндекс.расписаний и aviasales) в единый набор данных.
#
# - Создание графа:
#   - функция `build_route_graph` строит ориентированный граф с помощью networkx (`nx.MultiDiGraph`), где узлами являются станции, а ребрами – сегменты маршрутов;
#   - вес ребра определяется временем в пути или стоимостью, в зависимости от выбранного пользователем параметра (time или cost);
#   - при наличии промежуточного узла дополнительно проверяется, чтобы время пересадки было не меньше заданного порога.
#
# - Преобразование графа:
#   - функция `convert_multidigraph_to_digraph` преобразует multidigraph в digraph, оставляя только ребро с минимальным весом между двумя узлами, если их несколько.
#
# ---
#
# ### 7. Поиск оптимальных маршрутов и вывод результата
#
# - Поиск маршрутов:
#   - функция `find_k_shortest_paths` ищет до 10 кратчайших путей в построенном графе с использованием алгоритма поиска кратчайших простых путей.
#
# - Формирование итоговой таблицы:
#   - функция `build_optimal_route_dataframe` создаёт dataframe с подробной информацией по каждому сегменту маршрута (коды станций, названия, время отправления и прибытия, длительность пути, вид транспорта);
#   - все маршруты объединяются в один итоговый dataframe, который сортируется и выводится с помощью `display`.
#
# - Сохранение результата:
#   - итоговый dataframe сохраняется в csv-файл для последующего использования.
#
# ---
#
# **Таким образом, код выполняет комплексную задачу: от получения и обработки справочных данных, выбора транспортных узлов, запроса маршрутов через api, построения графа маршрутов, поиска оптимальных маршрутов до их наглядного представления и сохранения в файлы**

# %% [markdown]
# ## Загрузка библиотек

# %%
import os
import json
import logging
import requests
import pandas as pd
import networkx as nx
from networkx.algorithms.simple_paths import shortest_simple_paths
from datetime import datetime, timedelta
from typing import Any, Dict, List, Tuple, Union
from time import sleep
from IPython.display import display

# %% [markdown]
# ## Выполнение кода

# %%
logging.basicConfig(
    level=logging.WARNING,
    format="%(asctime)s [%(levelname)s] %(name)s - %(message)s"
)
logger = logging.getLogger("RouteSystem")

STATIONS_CACHE_JSON = "stations_list.json"
STATIONS_CACHE_CSV = "stations_list.csv"
YANDEX_RASP_API_KEY = "2a22163d-023f-47db-a974-6d683c413a83"
AVIASALES_TOKEN = "dbd789b8fa1dadd43c5376abdcba15a0"
AVIASALES_API_URL = "https://api.travelpayouts.com/v2/prices/latest"
URL_STATIONS_LIST = "https://api.rasp.yandex.net/v3.0/stations_list"
URL_SEARCH = "https://api.rasp.yandex.net/v3.0/search/"
SELECTED_NODES_FILE = "selected_nodes.json"
MIN_TRANSFER_TIME = 1800
YANDEX_TO_IATA_MAP = {
    "s9600370": "SVO",
    "s9600363": "VKO",
}

def get_aviasales_price(origin_iata: str, destination_iata: str, departure_date: str) -> float:
    try:
        params = {
            "origin": origin_iata,
            "destination": destination_iata,
            "departure_at": departure_date,
            "one_way": "true",
            "currency": "RUB",
            "token": AVIASALES_TOKEN,
            "limit": 1,
            "sorting": "price"
        }
        logger.info(f"Aviasales: запрос для {origin_iata} -> {destination_iata} на {departure_date}")
        resp = requests.get(AVIASALES_API_URL, params=params)
        resp.raise_for_status()
        data = resp.json()
        tickets = data.get("data", [])
        if not tickets:
            return None
        first_ticket = tickets[0]
        price_value = first_ticket.get("price")
        return float(price_value) if price_value else None
    except Exception as e:
        logger.error(f"Aviasales: ошибка запроса цены: {e}")
        return None

def fetch_stations_list_from_api(api_key: str) -> dict:
    logger.info("Запрос списка станций из API Яндекс.Расписаний...")
    params = {"apikey": api_key, "lang": "ru_RU", "format": "json"}
    response = requests.get(URL_STATIONS_LIST, params=params)
    response.raise_for_status()
    data = response.json()
    logger.info("Список станций получен.")
    return data

def stations_to_dataframe(stations_json: dict) -> pd.DataFrame:
    stations_list = []
    for country in stations_json.get("countries", []):
        for region in country.get("regions", []):
            for settlement in region.get("settlements", []):
                for station in settlement.get("stations", []):
                    station["settlement_title"] = settlement.get("title", "")
                    station["region_title"] = region.get("title", "")
                    station["country_title"] = country.get("title", "")
                    if "type" not in station:
                        station["type"] = "station"
                    stations_list.append(station)
    df = pd.json_normalize(stations_list)
    df = df[df["country_title"].str.contains("Россия", case=False, na=False)]
    return df

def load_stations_dataframe() -> (pd.DataFrame, dict):
    if os.path.exists(STATIONS_CACHE_CSV) and os.path.exists(STATIONS_CACHE_JSON):
        logger.info(f"Найден CSV-кэш: {STATIONS_CACHE_CSV}")
        df = pd.read_csv(STATIONS_CACHE_CSV, encoding="utf-8", low_memory=False)
        if "settlement_title" not in df.columns:
            logger.info("CSV-кэш не содержит 'settlement_title', пересоздаем DataFrame")
            with open(STATIONS_CACHE_JSON, "r", encoding="utf-8") as f:
                stations_json = json.load(f)
            df = stations_to_dataframe(stations_json)
            df.to_csv(STATIONS_CACHE_CSV, index=False, encoding="utf-8")
        else:
            with open(STATIONS_CACHE_JSON, "r", encoding="utf-8") as f:
                stations_json = json.load(f)
    else:
        logger.info("Кэш не найден, запрашиваем данные через API...")
        stations_json = fetch_stations_list_from_api(YANDEX_RASP_API_KEY)
        with open(STATIONS_CACHE_JSON, "w", encoding="utf-8") as f:
            json.dump(stations_json, f, ensure_ascii=False, indent=2)
        df = stations_to_dataframe(stations_json)
        df.to_csv(STATIONS_CACHE_CSV, index=False, encoding="utf-8")
    return df, stations_json

def load_settlements_dataframe() -> pd.DataFrame:
    if not os.path.exists(STATIONS_CACHE_JSON):
        logger.error(f"Файл {STATIONS_CACHE_JSON} не найден.")
        return pd.DataFrame()
    with open(STATIONS_CACHE_JSON, "r", encoding="utf-8") as f:
        stations_json = json.load(f)
    settlements_list = []
    for country in stations_json.get("countries", []):
        for region in country.get("regions", []):
            for settlement in region.get("settlements", []):
                settlement_copy = settlement.copy()
                settlement_copy["country_title"] = country.get("title", "")
                settlement_copy["region_title"] = region.get("title", "")
                settlement_copy["settlement_title"] = settlement.get("title", "")
                if "type" not in settlement_copy:
                    settlement_copy["type"] = "settlement"
                settlements_list.append(settlement_copy)
    df = pd.json_normalize(settlements_list)
    df = df[df["country_title"].str.contains("Россия", case=False, na=False)]
    return df

def filter_airports_and_train_stations(df: pd.DataFrame, city: str) -> pd.DataFrame:
    if "station_type" not in df.columns:
        df["station_type"] = ""
    mask = (df["settlement_title"].str.contains(city, case=False, na=False)) | \
           (df["title"].str.contains(city, case=False, na=False))
    df_city = df[mask]
    if "type" in df_city.columns:
        df_city = df_city[df_city["type"].str.lower() != "settlement"]
    valid_types = ["airport", "train_station"]
    df_filtered = df_city[df_city["station_type"].str.lower().isin(valid_types)]
    df_filtered = df_filtered[~df_filtered["title"].str.contains("Тур", case=False, na=False)]
    return df_filtered

def choose_station_interactive(df: pd.DataFrame, city: str) -> str:
    df_filtered = filter_airports_and_train_stations(df, city)
    if df_filtered.empty:
        logger.warning(f"В городе '{city}' не найдено транспортных узлов.")
        return ""
    if len(df_filtered) == 1:
        chosen = df_filtered.iloc[0]
        code = chosen.get("codes.yandex_code") or chosen.get("code", "")
        logger.info(f"Единственный вариант для '{city}': {code}")
        return code
    print(f"\nВ городе '{city}' найдено несколько вариантов:")
    df_filtered = df_filtered.reset_index(drop=True)
    for idx, row in df_filtered.iterrows():
        station_name = row.get("title", "Неизвестно")
        station_type = row.get("station_type", "Неизвестно")
        region = row.get("region_title", "")
        print(f"{idx}: {station_name} (Тип: {station_type}, Регион: {region})")
    try:
        choice = int(input("Введите номер выбранного узла: ").strip())
        if 0 <= choice < len(df_filtered):
            chosen = df_filtered.loc[choice]
            code = chosen.get("codes.yandex_code") or chosen.get("code", "")
            logger.info(f"Выбранный узел для '{city}': {code}")
            return code
        else:
            logger.error("Неверный выбор: номер вне диапазона.")
            return ""
    except Exception as e:
        logger.error(f"Ошибка ввода: {e}")
        return ""

def get_all_city_codes_automatic(df_settlements: pd.DataFrame, city: str, df_stations: pd.DataFrame) -> List[str]:
    if "codes.yandex_code" in df_stations.columns:
        col = "codes.yandex_code"
    elif "code" in df_stations.columns:
        col = "code"
    else:
        logger.error("Столбец с кодом не найден.")
        return []
    df_candidates = df_stations[
        (df_stations["settlement_title"].str.contains(city, case=False, na=False)) &
        (df_stations[col].str.startswith("s"))
    ]
    if not df_candidates.empty:
        codes = df_candidates[col].tolist()
        logger.info(f"Найдено {len(codes)} кодов для '{city}': {codes}")
        return codes
    else:
        logger.warning(f"Для '{city}' нет записей с кодом, начинающимся на 's'.")
        return []

def update_node_code(node: str, city: str, df: pd.DataFrame) -> str:
    if not node.startswith("c"):
        return node
    if "settlement_title" not in df.columns:
        logger.error("Нет столбца 'settlement_title'.")
        return node
    if "codes.yandex_code" in df.columns:
        col = "codes.yandex_code"
    elif "code" in df.columns:
        col = "code"
    else:
        logger.error("Столбец с кодом не найден.")
        return node
    df_candidate = df[
        (df["settlement_title"].str.contains(city, case=False, na=False)) &
        (df[col].str.startswith("s"))
    ]
    if not df_candidate.empty:
        candidate_station = df_candidate.iloc[0][col]
        logger.info(f"Обновляем {node} -> {candidate_station} для '{city}'")
        return candidate_station
    else:
        logger.warning(f"Подходящий код для '{city}' не найден, остаётся {node}")
        return node

def select_transport_node(city: str, df_stations: pd.DataFrame, df_settlements: pd.DataFrame) -> Union[str, List[str]]:
    if city.lower() in ["москва", "санкт-петербург"]:
        return choose_station_interactive(df_stations, city)
    else:
        codes = get_all_city_codes_automatic(df_settlements, city, df_stations)
        return [update_node_code(code, city, df_stations) for code in codes]

def input_route_parameters() -> dict:
    city_from = input("Введите город/код отправления: ").strip()
    city_to = input("Введите город/код прибытия: ").strip()
    date_str = input("Введите дату (YYYY-MM-DD): ").strip()
    try:
        dt_obj = datetime.strptime(date_str, "%Y-%m-%d")
        if dt_obj.date() < datetime.now().date():
            logger.error("Дата в прошлом.")
            return {}
    except ValueError:
        logger.error("Неверный формат даты. Ожидается YYYY-MM-DD.")
        return {}
    choice = input("Хотите остановку в промежуточном городе? (Да/Нет): ").strip().lower()
    work_info = None
    if choice in ["да", "yes"]:
        wcity = input("Введите город/код промежуточного узла: ").strip()
        try:
            wdays = int(input("Сколько суток остановка (1..7): ").strip())
            if not (1 <= wdays <= 7):
                logger.error("Число суток должно быть от 1 до 7.")
                return {}
            work_info = (wcity, wdays)
        except ValueError:
            logger.error("Неверный ввод числа суток.")
            return {}
    return {"city_from": city_from, "city_to": city_to, "date": date_str, "work_info": work_info}

def get_route_options(from_code: str, to_code: str, date: str,
                      transport_types: str = "plane,train,suburban,bus,water,helicopter",
                      transfers: str = "true", limit: int = 100, offset: int = 0) -> dict:
    params = {
        "apikey": YANDEX_RASP_API_KEY,
        "format": "json",
        "from": from_code,
        "to": to_code,
        "lang": "ru_RU",
        "date": date,
        "transport_types": transport_types,
        "transfers": transfers,
        "limit": limit,
        "offset": offset
    }
    logger.info(f"Yandex: запрос {from_code} -> {to_code} на {date}")
    r = requests.get(URL_SEARCH, params=params)
    try:
        r.raise_for_status()
    except requests.exceptions.HTTPError as e:
        if r.status_code == 404:
            logger.warning(f"Yandex: маршруты не найдены для {params}")
            return {}
        else:
            logger.error(f"Yandex: HTTP ошибка: {e} (Статус: {r.status_code})")
            raise
    logger.info("Yandex: маршруты получены.")
    return r.json()

def save_route_options(route_data: dict, filename: str) -> None:
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(route_data, f, ensure_ascii=False, indent=2)
    logger.info(f"Сохранён JSON: {filename}")
    if "segments" in route_data:
        df = pd.json_normalize(route_data["segments"])
        csv_name = filename.replace(".json", ".csv")
        df.to_csv(csv_name, index=False, encoding="utf-8")
        logger.info(f"Сохранён CSV: {csv_name}")

def iata_to_yandex(iata: str) -> str:
    for yandex_code, code in YANDEX_TO_IATA_MAP.items():
        if code == iata:
            return yandex_code
    return iata

def yandex_to_iata(yandex_code: str) -> str:
    return YANDEX_TO_IATA_MAP.get(yandex_code, yandex_code)

def get_aviasales_routes(origin_iata: str, destination_iata: str, departure_date: str) -> dict:
    try:
        params = {
            "origin": origin_iata,
            "destination": destination_iata,
            "departure_at": departure_date,
            "one_way": "true",
            "currency": "RUB",
            "token": AVIASALES_TOKEN,
            "limit": 10,
            "sorting": "price"
        }
        logger.info(f"Aviasales: запрос {origin_iata} -> {destination_iata} на {departure_date}")
        resp = requests.get(AVIASALES_API_URL, params=params)
        resp.raise_for_status()
        data = resp.json()
        tickets = data.get("data", [])
        segments = []
        for ticket in tickets:
            dep_str = ticket.get("departure_at")
            if not dep_str:
                continue
            try:
                dep_dt = datetime.fromisoformat(dep_str)
            except Exception:
                continue
            duration_minutes = ticket.get("duration")
            if duration_minutes:
                arr_dt = dep_dt + timedelta(minutes=duration_minutes)
                arr_str = arr_dt.isoformat()
            else:
                arr_str = ""
            segment = {
                "from": {"code": iata_to_yandex(ticket.get("origin", "")), "title": ticket.get("origin", "")},
                "to": {"code": iata_to_yandex(ticket.get("destination", "")), "title": ticket.get("destination", "")},
                "departure": dep_str,
                "arrival": arr_str,
                "transport_type": "plane",
                "thread": {"transport_type": "plane", "carrier": ticket.get("airline", "")},
                "cost": float(ticket.get("price", 0)),
                "query": 3
            }
            segments.append(segment)
        logger.info(f"Aviasales: получено сегментов: {len(segments)}")
        return {"segments": segments, "search": {"from": {"code": origin_iata}, "to": {"code": destination_iata}}}
    except Exception as e:
        logger.error(f"Aviasales: ошибка запроса маршрутов: {e}")
        return {}

def save_aviasales_route_options(route_data: dict, filename: str) -> None:
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(route_data, f, ensure_ascii=False, indent=2)
    logger.info(f"Aviasales: сохранён JSON: {filename}")
    if "segments" in route_data:
        df = pd.json_normalize(route_data["segments"])
        csv_name = filename.replace(".json", ".csv")
        df.to_csv(csv_name, index=False, encoding="utf-8")
        logger.info(f"Aviasales: сохранён CSV: {csv_name}")

def convert_multidigraph_to_digraph(G: nx.MultiDiGraph) -> nx.DiGraph:
    H = nx.DiGraph()
    for u, v, data in G.edges(data=True):
        w = data.get("weight", 0)
        if H.has_edge(u, v):
            if w < H[u][v]["weight"]:
                H[u][v]["weight"] = w
                H[u][v]["time"] = data.get("time")
                H[u][v]["cost"] = data.get("cost")
                H[u][v]["segment"] = data.get("segment")
        else:
            H.add_edge(u, v, weight=w, time=data.get("time"), cost=data.get("cost"), segment=data.get("segment"))
    return H

def combine_route_data(route_datas: List[dict], from_nodes: List[str], to_nodes: List[str]) -> dict:
    combined_segments = []
    for rd in route_datas:
        segs = rd.get("segments", [])
        for s in segs:
            if "query" not in s:
                s["query"] = 1
            combined_segments.append(s)
    logger.info(f"Объединено сегментов: {len(combined_segments)}")
    return {"segments": combined_segments, "search": {"from": {"codes": from_nodes}, "to": {"codes": to_nodes}}}

def build_route_graph(route_data: dict, intermediate_node: Union[str, None] = None, ranking_param: str = "time") -> nx.MultiDiGraph:
    G = nx.MultiDiGraph()
    segments = route_data.get("segments", [])
    interval_segments = route_data.get("interval_segments", [])
    all_segments = segments + interval_segments
    logger.info(f"Построение графа: найдено {len(all_segments)} сегментов")
    min_arrival = None
    if intermediate_node:
        for s in all_segments:
            if s.get("query") == 1:
                to_st = s.get("to", {})
                if to_st.get("code") == intermediate_node:
                    arr_str = s.get("arrival")
                    if arr_str:
                        try:
                            arr_dt = datetime.fromisoformat(arr_str)
                            if (min_arrival is None) or (arr_dt < min_arrival):
                                min_arrival = arr_dt
                        except ValueError:
                            pass
        if min_arrival:
            logger.info(f"Минимальное время прибытия в {intermediate_node}: {min_arrival.isoformat()}")
    for s in all_segments:
        try:
            from_st = s.get("from", {})
            to_st = s.get("to", {})
            from_code = from_st.get("code")
            to_code = to_st.get("code")
            if not from_code or not to_code:
                continue
            dep_str = s.get("departure")
            arr_str = s.get("arrival")
            if not dep_str or not arr_str:
                continue
            try:
                dep_dt = datetime.fromisoformat(dep_str)
                arr_dt = datetime.fromisoformat(arr_str)
                duration = (arr_dt - dep_dt).total_seconds()
                if duration < 0:
                    continue
            except Exception:
                continue
            if intermediate_node and s.get("query") == 2 and from_code == intermediate_node and min_arrival:
                gap = (dep_dt - min_arrival).total_seconds()
                if gap < MIN_TRANSFER_TIME:
                    logger.info(f"Сегмент исключён (пересадка {gap} сек)")
                    continue
            cost_value = None
            transport_type = s.get("thread", {}).get("transport_type", "") or s.get("transport_type", "")
            if transport_type == "plane":
                iata_origin = YANDEX_TO_IATA_MAP.get(from_code)
                iata_destination = YANDEX_TO_IATA_MAP.get(to_code)
                if iata_origin and iata_destination:
                    dep_date_str = dep_dt.strftime("%Y-%m-%d")
                    cost_value = get_aviasales_price(iata_origin, iata_destination, dep_date_str)
            weight = duration if ranking_param == "time" else (float(cost_value) if cost_value is not None else 999999.0)
            G.add_edge(from_code, to_code, weight=weight, time=duration, cost=cost_value, segment=s)
        except Exception as e:
            logger.error(f"Ошибка обработки сегмента: {e}")
    logger.info(f"Граф построен: узлов={G.number_of_nodes()}, рёбер={G.number_of_edges()}")
    return G

def find_k_shortest_paths(G: nx.MultiDiGraph, source: str, target: str, k: int = 10) -> List[Tuple[List[str], float]]:
    H = convert_multidigraph_to_digraph(G)
    if source not in H or target not in H:
        logger.warning(f"Узел {source} или {target} отсутствует в графе.")
        return []
    paths_gen = shortest_simple_paths(H, source, target, weight="weight")
    results = []
    for path in paths_gen:
        total_weight = sum(H[u][v]["weight"] for u, v in zip(path, path[1:]))
        results.append((path, total_weight))
        if len(results) >= k:
            break
    return results

def format_duration(seconds: float) -> str:
    if seconds is None:
        return ""
    hh = int(seconds // 3600)
    mm = int((seconds % 3600) // 60)
    ss = int(seconds % 60)
    return f"{hh}ч {mm}м {ss}с"

def build_optimal_route_dataframe(route: List[str], graph: nx.MultiDiGraph, work_days: int = 0, route_id: int = 1) -> pd.DataFrame:
    rows = []
    for i in range(len(route) - 1):
        from_node = route[i]
        to_node = route[i + 1]
        edge_data = list(graph.get_edge_data(from_node, to_node).values())[0] if graph.has_edge(from_node, to_node) else {}
        seg = edge_data.get("segment", {}) if edge_data else {}
        from_st = seg.get("from", {})
        to_st = seg.get("to", {})
        from_code = from_st.get("code", from_node)
        to_code = to_st.get("code", to_node)
        from_title = from_st.get("title", "")
        to_title = to_st.get("title", "")
        dep_time = seg.get("departure", "")
        arr_time = seg.get("arrival", "")
        duration_seconds = None
        if dep_time and arr_time:
            try:
                dep_dt = datetime.fromisoformat(dep_time)
                arr_dt = datetime.fromisoformat(arr_time)
                duration_seconds = (arr_dt - dep_dt).total_seconds()
            except Exception:
                pass
        dur_str = format_duration(duration_seconds)
        transport_type = seg.get("thread", {}).get("transport_type", "") or seg.get("transport_type", "")
        rows.append({
            "Маршрут_ID": route_id,
            "Номер сегмента": i + 1,
            "Код отправления": from_code,
            "Город отправления": from_title,
            "Время отправления": dep_time,
            "Код прибытия": to_code,
            "Город прибытия": to_title,
            "Время прибытия": arr_time,
            "Остановок (суток)": work_days,
            "Время в пути": dur_str,
            "Вид транспорта": transport_type
        })
    return pd.DataFrame(rows)

def choose_valid_route_nodes(from_nodes: Union[str, List[str]], to_nodes: Union[str, List[str]], graph: nx.MultiDiGraph) -> Tuple[Union[str, None], Union[str, None]]:
    if isinstance(from_nodes, str):
        from_nodes = [from_nodes]
    if isinstance(to_nodes, str):
        to_nodes = [to_nodes]
    for f in from_nodes:
        for t in to_nodes:
            if f in graph.nodes and t in graph.nodes:
                return f, t
    return None, None

def main():
    params = input_route_parameters()
    if not params:
        return
    city_from = params["city_from"]
    city_to = params["city_to"]
    date_str = params["date"]
    work_info = params.get("work_info")
    ranking_param = input("По какому параметру искать маршрут? (time/cost): ").strip().lower()
    if ranking_param not in ("time", "cost"):
        ranking_param = "time"
    df_stations, _ = load_stations_dataframe()
    df_settlements = load_settlements_dataframe()
    if df_stations.empty or df_settlements.empty:
        print("Нет справочных данных для поиска.")
        return
    if city_from.lower() in ["москва", "санкт-петербург"]:
        from_nodes = [select_transport_node(city_from, df_stations, df_settlements)]
    else:
        from_nodes = select_transport_node(city_from, df_stations, df_settlements)
    if city_to.lower() in ["москва", "санкт-петербург"]:
        to_nodes = [select_transport_node(city_to, df_stations, df_settlements)]
    else:
        to_nodes = select_transport_node(city_to, df_stations, df_settlements)
    if not from_nodes or not to_nodes:
        print("Не удалось выбрать транспортные узлы для одного из городов.")
        return
    work_nodes = []
    work_days = 0
    if work_info:
        work_city, work_days = work_info
        if work_city.lower() in ["москва", "санкт-петербург"]:
            work_nodes = [select_transport_node(work_city, df_stations, df_settlements)]
        else:
            work_nodes = select_transport_node(work_city, df_stations, df_settlements)
    selected_nodes = {"from_nodes": from_nodes, "to_nodes": to_nodes}
    if work_nodes:
        selected_nodes["work_nodes"] = work_nodes
    with open(SELECTED_NODES_FILE, "w", encoding="utf-8") as f:
        json.dump(selected_nodes, f, ensure_ascii=False, indent=2)
    print("\nПоиск маршрутов выполняется по Яндекс.Расписаниям...")
    route_datas = []
    if work_nodes:
        seg1_datas = []
        for f in from_nodes:
            for w in work_nodes:
                rd1 = get_route_options(f, w, date_str)
                if rd1.get("segments"):
                    seg1_datas.append(rd1)
        if not seg1_datas:
            print("Маршруты по Яндекс.Расписаниям не найдены.")
            return
        first_seg = seg1_datas[0]["segments"][0]
        arrival_str = first_seg.get("arrival")
        if not arrival_str:
            print("Маршруты по Яндекс.Расписаниям не найдены (нет времени прибытия).")
            return
        arrival_dt = datetime.fromisoformat(arrival_str)
        new_date_str = (arrival_dt + timedelta(days=work_days)).strftime("%Y-%m-%d")
        seg2_datas = []
        for w in work_nodes:
            for t in to_nodes:
                rd2 = get_route_options(w, t, new_date_str)
                if rd2.get("segments"):
                    seg2_datas.append(rd2)
        if not seg2_datas:
            print("Маршруты по Яндекс.Расписаниям не найдены для второго сегмента.")
            return
        route_datas = seg1_datas + seg2_datas
    else:
        for f in from_nodes:
            for t in to_nodes:
                rd = get_route_options(f, t, date_str)
                if rd.get("segments"):
                    route_datas.append(rd)
        if not route_datas:
            print("Маршруты по Яндекс.Расписаниям не найдены.")
            return
    print("Маршруты по Яндекс.Расписаниям найдены.")
    fname_yandex = f"search_{city_from}_{city_to}_{date_str}.json".replace(" ", "_")
    combined_yandex = combine_route_data(route_datas, from_nodes, to_nodes)
    save_route_options(combined_yandex, fname_yandex)
    print("\nВыполняется поиск маршрутов по Aviasales...")
    aviasales_datas = []
    for f in from_nodes:
        origin_iata = yandex_to_iata(f)
        for t in to_nodes:
            destination_iata = yandex_to_iata(t)
            data = get_aviasales_routes(origin_iata, destination_iata, date_str)
            if data.get("segments"):
                aviasales_datas.append(data)
    if aviasales_datas:
        print("Маршруты по Aviasales найдены.")
        fname_av = f"aviasales_{city_from}_{city_to}_{date_str}.json".replace(" ", "_")
        combined_av = combine_route_data(aviasales_datas, from_nodes, to_nodes)
        save_aviasales_route_options(combined_av, fname_av)
    else:
        print("Маршруты по Aviasales не найдены.")
    combined_segments = combined_yandex.get("segments", [])
    if aviasales_datas:
        combined_segments += combine_route_data(aviasales_datas, from_nodes, to_nodes).get("segments", [])
    combined_data = {"segments": combined_segments, "search": combined_yandex.get("search", {})}
    fname_combined = f"combined_{city_from}_{city_to}_{date_str}.json".replace(" ", "_")
    save_route_options(combined_data, fname_combined)
    graph = build_route_graph(combined_data, intermediate_node=(work_nodes[0] if work_nodes else None), ranking_param=ranking_param)
    if graph.number_of_nodes() == 0:
        print("Маршруты не найдены (граф пуст).")
        return
    start_node, end_node = choose_valid_route_nodes(from_nodes, to_nodes, graph)
    if start_node is None or end_node is None:
        print("Маршруты не найдены (нет валидных узлов в графе).")
        return
    routes = find_k_shortest_paths(graph, start_node, end_node, k=10)
    if not routes:
        print("Маршруты не найдены (нет путей в графе).")
        return
    all_frames = []
    for idx, (path_nodes, total_val) in enumerate(routes, start=1):
        df_route = build_optimal_route_dataframe(
            path_nodes,
            graph,
            work_days=(work_days if work_info else 0),
            route_id=idx
        )
        if ranking_param == "cost":
            df_route["Общая_стоимость"] = total_val
        all_frames.append(df_route)
    df_all = pd.concat(all_frames, ignore_index=True)
    df_all.sort_values(["Маршрут_ID", "Номер сегмента"], inplace=True)
    print("\n=== Найденные маршруты (до 10) ===")
    display(df_all)
    output_filename = "k_shortest_paths_result_time.csv" if ranking_param == "time" else "k_shortest_paths_result.csv"
    df_all.to_csv(output_filename, index=False, encoding="utf-8")

if __name__ == "__main__":
    main()
# Out:
# Введите город/код отправления:  Колпино
# Введите город/код прибытия:  Санкт-Петербург
# Введите дату (YYYY-MM-DD):  2025-03-17
# Хотите остановку в промежуточном городе? (Да/Нет):  Нет
# По какому параметру искать маршрут? (time/cost):  time
# 2025-03-16 22:41:08,604 [INFO] RouteSystem - Кэш не найден, запрашиваем данные через API...
# 2025-03-16 22:41:08,606 [INFO] RouteSystem - Запрос списка станций из API Яндекс.Расписаний...
# 2025-03-16 22:41:13,259 [INFO] RouteSystem - Список станций получен.
# 2025-03-16 22:41:22,692 [INFO] RouteSystem - Найдено 96 кодов для 'Колпино': ['s9602657', 's9838091', 's9768428', 's9799209', 's9811419', 's9815244', 's9818505', 's9603634', 's9811416', 's9811417', 's9811420', 's9811426', 's9811427', 's9811428', 's9811429', 's9811433', 's9815222', 's9815245', 's9818232', 's9818233', 's9818450', 's9818451', 's9818456', 's9818457', 's9818508', 's9818509', 's9818510', 's9818511', 's9818513', 's9818516', 's9818517', 's9818518', 's9818519', 's9818521', 's9818522', 's9818523', 's9818524', 's9818525', 's9818527', 's9818529', 's9818530', 's9818542', 's9818543', 's9818544', 's9818545', 's9818546', 's9818547', 's9818549', 's9818550', 's9819286', 's9819287', 's9819291', 's9819292', 's9819293', 's9819294', 's9819295', 's9819397', 's9821647', 's9837725', 's9837879', 's9837940', 's9838065', 's9838066', 's9838077', 's9838078', 's9838183', 's9850590', 's9859177', 's9859178', 's9867679', 's9867680', 's9867681', 's9867682', 's9872499', 's9874097', 's9874098', 's9874099', 's9874100', 's9875438', 's9875439', 's9875440', 's9875441', 's9875442', 's9875443', 's9878650', 's9880865', 's9881827', 's9881828', 's9882594', 's9882879', 's9883284', 's9885904', 's9886030', 's9886185', 's9887953', 's9888121']
# В городе 'Санкт-Петербург' найдено несколько вариантов:
# 0: Пулково (Тип: airport, Регион: Санкт-Петербург и Ленинградская область)
# 1: Санкт-Петербург (Московский вокзал) (Тип: train_station, Регион: Санкт-Петербург и Ленинградская область)
# 2: Санкт-Петербург (Витебский вокзал) (Тип: train_station, Регион: Санкт-Петербург и Ленинградская область)
# 3: Санкт-Петербург (Финляндский вокзал) (Тип: train_station, Регион: Санкт-Петербург и Ленинградская область)
# 4: Санкт-Петербург (Балтийский вокзал) (Тип: train_station, Регион: Санкт-Петербург и Ленинградская область)
# 5: Санкт-Петербург (Ладожский вокзал) (Тип: train_station, Регион: Санкт-Петербург и Ленинградская область)
# Введите номер выбранного узла:  1
# 2025-03-16 22:41:43,532 [INFO] RouteSystem - Выбранный узел для 'Санкт-Петербург': s9602494
# 2025-03-16 22:41:43,534 [INFO] RouteSystem - Yandex: запрос s9602657 -> s9602494 на 2025-03-17
# Поиск маршрутов выполняется по Яндекс.Расписаниям...
# 2025-03-16 22:41:44,319 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:44,323 [INFO] RouteSystem - Yandex: запрос s9838091 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:45,098 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:45,139 [INFO] RouteSystem - Yandex: запрос s9768428 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:45,974 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:45,977 [INFO] RouteSystem - Yandex: запрос s9799209 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:46,491 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9799209', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:41:46,493 [INFO] RouteSystem - Yandex: запрос s9811419 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:47,613 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:47,616 [INFO] RouteSystem - Yandex: запрос s9815244 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:49,227 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:49,230 [INFO] RouteSystem - Yandex: запрос s9818505 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:50,100 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:50,104 [INFO] RouteSystem - Yandex: запрос s9603634 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:51,407 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:51,410 [INFO] RouteSystem - Yandex: запрос s9811416 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:52,012 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:52,012 [INFO] RouteSystem - Yandex: запрос s9811417 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:52,698 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:52,701 [INFO] RouteSystem - Yandex: запрос s9811420 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:53,795 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:53,797 [INFO] RouteSystem - Yandex: запрос s9811426 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:54,441 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:54,443 [INFO] RouteSystem - Yandex: запрос s9811427 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:55,224 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:55,227 [INFO] RouteSystem - Yandex: запрос s9811428 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:56,546 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:56,549 [INFO] RouteSystem - Yandex: запрос s9811429 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:57,135 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:57,137 [INFO] RouteSystem - Yandex: запрос s9811433 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:57,857 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:57,859 [INFO] RouteSystem - Yandex: запрос s9815222 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:58,558 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:58,561 [INFO] RouteSystem - Yandex: запрос s9815245 -> s9602494 на 2025-03-17
# 2025-03-16 22:41:59,925 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:41:59,928 [INFO] RouteSystem - Yandex: запрос s9818232 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:00,558 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:00,561 [INFO] RouteSystem - Yandex: запрос s9818233 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:01,674 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:01,677 [INFO] RouteSystem - Yandex: запрос s9818450 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:02,247 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:02,250 [INFO] RouteSystem - Yandex: запрос s9818451 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:02,886 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:02,888 [INFO] RouteSystem - Yandex: запрос s9818456 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:03,879 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:03,885 [INFO] RouteSystem - Yandex: запрос s9818457 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:04,564 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:04,568 [INFO] RouteSystem - Yandex: запрос s9818508 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:05,122 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:05,124 [INFO] RouteSystem - Yandex: запрос s9818509 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:05,989 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:05,993 [INFO] RouteSystem - Yandex: запрос s9818510 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:06,600 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:06,602 [INFO] RouteSystem - Yandex: запрос s9818511 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:07,161 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:07,164 [INFO] RouteSystem - Yandex: запрос s9818513 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:08,030 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:08,033 [INFO] RouteSystem - Yandex: запрос s9818516 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:09,115 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:09,118 [INFO] RouteSystem - Yandex: запрос s9818517 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:09,885 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:09,887 [INFO] RouteSystem - Yandex: запрос s9818518 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:11,118 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:11,122 [INFO] RouteSystem - Yandex: запрос s9818519 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:11,752 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:11,754 [INFO] RouteSystem - Yandex: запрос s9818521 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:12,377 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:12,380 [INFO] RouteSystem - Yandex: запрос s9818522 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:14,080 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:14,082 [INFO] RouteSystem - Yandex: запрос s9818523 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:14,695 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:14,697 [INFO] RouteSystem - Yandex: запрос s9818524 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:15,645 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:15,648 [INFO] RouteSystem - Yandex: запрос s9818525 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:16,439 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:16,442 [INFO] RouteSystem - Yandex: запрос s9818527 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:17,109 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:17,112 [INFO] RouteSystem - Yandex: запрос s9818529 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:17,908 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:17,910 [INFO] RouteSystem - Yandex: запрос s9818530 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:18,519 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:18,521 [INFO] RouteSystem - Yandex: запрос s9818542 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:19,031 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9818542', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:42:19,034 [INFO] RouteSystem - Yandex: запрос s9818543 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:20,109 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:20,113 [INFO] RouteSystem - Yandex: запрос s9818544 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:21,152 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:21,155 [INFO] RouteSystem - Yandex: запрос s9818545 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:21,727 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:21,728 [INFO] RouteSystem - Yandex: запрос s9818546 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:22,753 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:22,756 [INFO] RouteSystem - Yandex: запрос s9818547 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:23,835 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:23,837 [INFO] RouteSystem - Yandex: запрос s9818549 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:25,374 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:25,376 [INFO] RouteSystem - Yandex: запрос s9818550 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:25,989 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:25,994 [INFO] RouteSystem - Yandex: запрос s9819286 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:26,528 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:26,529 [INFO] RouteSystem - Yandex: запрос s9819287 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:27,594 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:27,597 [INFO] RouteSystem - Yandex: запрос s9819291 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:28,257 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:28,258 [INFO] RouteSystem - Yandex: запрос s9819292 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:28,777 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:28,778 [INFO] RouteSystem - Yandex: запрос s9819293 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:29,389 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:29,391 [INFO] RouteSystem - Yandex: запрос s9819294 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:29,943 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:29,945 [INFO] RouteSystem - Yandex: запрос s9819295 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:30,611 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:30,614 [INFO] RouteSystem - Yandex: запрос s9819397 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:31,271 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:31,273 [INFO] RouteSystem - Yandex: запрос s9821647 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:31,827 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:31,828 [INFO] RouteSystem - Yandex: запрос s9837725 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:32,406 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:32,409 [INFO] RouteSystem - Yandex: запрос s9837879 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:32,953 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:32,958 [INFO] RouteSystem - Yandex: запрос s9837940 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:34,052 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:34,057 [INFO] RouteSystem - Yandex: запрос s9838065 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:34,794 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:34,801 [INFO] RouteSystem - Yandex: запрос s9838066 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:35,738 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:35,742 [INFO] RouteSystem - Yandex: запрос s9838077 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:36,305 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9838077', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:42:36,307 [INFO] RouteSystem - Yandex: запрос s9838078 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:37,087 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:37,091 [INFO] RouteSystem - Yandex: запрос s9838183 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:37,778 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:37,780 [INFO] RouteSystem - Yandex: запрос s9850590 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:38,361 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:38,365 [INFO] RouteSystem - Yandex: запрос s9859177 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:38,936 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:38,937 [INFO] RouteSystem - Yandex: запрос s9859178 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:39,453 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:39,455 [INFO] RouteSystem - Yandex: запрос s9867679 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:40,264 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9867679', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:42:40,266 [INFO] RouteSystem - Yandex: запрос s9867680 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:40,869 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9867680', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:42:40,870 [INFO] RouteSystem - Yandex: запрос s9867681 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:41,516 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9867681', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:42:41,517 [INFO] RouteSystem - Yandex: запрос s9867682 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:42,112 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:42,114 [INFO] RouteSystem - Yandex: запрос s9872499 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:42,640 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9872499', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:42:42,644 [INFO] RouteSystem - Yandex: запрос s9874097 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:43,817 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:43,819 [INFO] RouteSystem - Yandex: запрос s9874098 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:44,434 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:44,441 [INFO] RouteSystem - Yandex: запрос s9874099 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:44,956 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:44,958 [INFO] RouteSystem - Yandex: запрос s9874100 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:45,579 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:45,583 [INFO] RouteSystem - Yandex: запрос s9875438 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:47,467 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:47,469 [INFO] RouteSystem - Yandex: запрос s9875439 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:48,157 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:48,159 [INFO] RouteSystem - Yandex: запрос s9875440 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:48,719 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:48,721 [INFO] RouteSystem - Yandex: запрос s9875441 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:49,280 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:49,282 [INFO] RouteSystem - Yandex: запрос s9875442 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:49,879 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:49,881 [INFO] RouteSystem - Yandex: запрос s9875443 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:50,519 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:50,521 [INFO] RouteSystem - Yandex: запрос s9878650 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:51,038 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:51,040 [INFO] RouteSystem - Yandex: запрос s9880865 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:51,584 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:51,585 [INFO] RouteSystem - Yandex: запрос s9881827 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:52,212 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:52,215 [INFO] RouteSystem - Yandex: запрос s9881828 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:52,784 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9881828', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:42:52,786 [INFO] RouteSystem - Yandex: запрос s9882594 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:53,393 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:53,395 [INFO] RouteSystem - Yandex: запрос s9882879 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:53,982 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:53,983 [INFO] RouteSystem - Yandex: запрос s9883284 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:54,521 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9883284', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:42:54,523 [INFO] RouteSystem - Yandex: запрос s9885904 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:55,140 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9885904', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:42:55,142 [INFO] RouteSystem - Yandex: запрос s9886030 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:55,712 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:55,714 [INFO] RouteSystem - Yandex: запрос s9886185 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:56,309 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9886185', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:42:56,310 [INFO] RouteSystem - Yandex: запрос s9887953 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:56,814 [WARNING] RouteSystem - Yandex: маршруты не найдены для {'apikey': '2a22163d-023f-47db-a974-6d683c413a83', 'format': 'json', 'from': 's9887953', 'to': 's9602494', 'lang': 'ru_RU', 'date': '2025-03-17', 'transport_types': 'plane,train,suburban,bus,water,helicopter', 'transfers': 'true', 'limit': 100, 'offset': 0}
# 2025-03-16 22:42:56,816 [INFO] RouteSystem - Yandex: запрос s9888121 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:57,850 [INFO] RouteSystem - Yandex: маршруты получены.
# 2025-03-16 22:42:57,853 [INFO] RouteSystem - Объединено сегментов: 658
# Маршруты по Яндекс.Расписаниям найдены.
# 2025-03-16 22:42:58,109 [INFO] RouteSystem - Сохранён JSON: search_Колпино_Санкт-Петербург_2025-03-17.json
# 2025-03-16 22:42:58,267 [INFO] RouteSystem - Сохранён CSV: search_Колпино_Санкт-Петербург_2025-03-17.csv
# 2025-03-16 22:42:58,270 [INFO] RouteSystem - Aviasales: запрос s9602657 -> s9602494 на 2025-03-17
# Выполняется поиск маршрутов по Aviasales...
# 2025-03-16 22:42:58,665 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9602657&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:42:58,667 [INFO] RouteSystem - Aviasales: запрос s9838091 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:59,033 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9838091&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:42:59,035 [INFO] RouteSystem - Aviasales: запрос s9768428 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:59,415 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9768428&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:42:59,417 [INFO] RouteSystem - Aviasales: запрос s9799209 -> s9602494 на 2025-03-17
# 2025-03-16 22:42:59,813 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9799209&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:42:59,815 [INFO] RouteSystem - Aviasales: запрос s9811419 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:00,819 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9811419&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:00,820 [INFO] RouteSystem - Aviasales: запрос s9815244 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:01,185 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9815244&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:01,188 [INFO] RouteSystem - Aviasales: запрос s9818505 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:01,569 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818505&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:01,571 [INFO] RouteSystem - Aviasales: запрос s9603634 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:01,992 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9603634&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:01,998 [INFO] RouteSystem - Aviasales: запрос s9811416 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:02,391 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9811416&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:02,393 [INFO] RouteSystem - Aviasales: запрос s9811417 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:03,031 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9811417&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:03,034 [INFO] RouteSystem - Aviasales: запрос s9811420 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:03,439 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9811420&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:03,441 [INFO] RouteSystem - Aviasales: запрос s9811426 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:03,888 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9811426&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:03,891 [INFO] RouteSystem - Aviasales: запрос s9811427 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:04,299 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9811427&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:04,305 [INFO] RouteSystem - Aviasales: запрос s9811428 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:04,672 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9811428&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:04,674 [INFO] RouteSystem - Aviasales: запрос s9811429 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:05,061 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9811429&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:05,065 [INFO] RouteSystem - Aviasales: запрос s9811433 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:05,437 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9811433&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:05,443 [INFO] RouteSystem - Aviasales: запрос s9815222 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:05,850 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9815222&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:05,852 [INFO] RouteSystem - Aviasales: запрос s9815245 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:06,289 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9815245&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:06,290 [INFO] RouteSystem - Aviasales: запрос s9818232 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:06,676 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818232&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:06,678 [INFO] RouteSystem - Aviasales: запрос s9818233 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:07,117 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818233&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:07,119 [INFO] RouteSystem - Aviasales: запрос s9818450 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:07,499 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818450&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:07,501 [INFO] RouteSystem - Aviasales: запрос s9818451 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:07,890 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818451&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:07,893 [INFO] RouteSystem - Aviasales: запрос s9818456 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:08,291 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818456&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:08,294 [INFO] RouteSystem - Aviasales: запрос s9818457 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:08,687 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818457&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:08,691 [INFO] RouteSystem - Aviasales: запрос s9818508 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:09,074 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818508&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:09,078 [INFO] RouteSystem - Aviasales: запрос s9818509 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:09,455 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818509&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:09,457 [INFO] RouteSystem - Aviasales: запрос s9818510 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:09,837 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818510&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:09,838 [INFO] RouteSystem - Aviasales: запрос s9818511 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:10,202 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818511&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:10,205 [INFO] RouteSystem - Aviasales: запрос s9818513 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:10,669 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818513&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:10,671 [INFO] RouteSystem - Aviasales: запрос s9818516 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:11,075 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818516&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:11,082 [INFO] RouteSystem - Aviasales: запрос s9818517 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:11,489 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818517&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:11,490 [INFO] RouteSystem - Aviasales: запрос s9818518 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:11,907 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818518&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:11,909 [INFO] RouteSystem - Aviasales: запрос s9818519 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:12,307 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818519&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:12,310 [INFO] RouteSystem - Aviasales: запрос s9818521 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:12,700 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818521&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:12,701 [INFO] RouteSystem - Aviasales: запрос s9818522 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:13,074 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818522&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:13,076 [INFO] RouteSystem - Aviasales: запрос s9818523 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:13,468 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818523&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:13,471 [INFO] RouteSystem - Aviasales: запрос s9818524 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:14,880 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818524&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:14,881 [INFO] RouteSystem - Aviasales: запрос s9818525 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:15,262 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818525&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:15,263 [INFO] RouteSystem - Aviasales: запрос s9818527 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:15,658 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818527&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:15,664 [INFO] RouteSystem - Aviasales: запрос s9818529 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:16,030 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818529&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:16,033 [INFO] RouteSystem - Aviasales: запрос s9818530 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:16,679 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818530&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:16,680 [INFO] RouteSystem - Aviasales: запрос s9818542 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:17,044 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818542&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:17,046 [INFO] RouteSystem - Aviasales: запрос s9818543 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:17,411 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818543&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:17,413 [INFO] RouteSystem - Aviasales: запрос s9818544 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:17,807 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818544&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:17,809 [INFO] RouteSystem - Aviasales: запрос s9818545 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:18,209 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818545&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:18,210 [INFO] RouteSystem - Aviasales: запрос s9818546 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:18,634 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818546&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:18,638 [INFO] RouteSystem - Aviasales: запрос s9818547 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:19,012 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818547&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:19,015 [INFO] RouteSystem - Aviasales: запрос s9818549 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:19,412 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818549&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:19,414 [INFO] RouteSystem - Aviasales: запрос s9818550 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:19,858 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9818550&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:19,860 [INFO] RouteSystem - Aviasales: запрос s9819286 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:20,252 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9819286&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:20,253 [INFO] RouteSystem - Aviasales: запрос s9819287 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:21,005 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9819287&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:21,006 [INFO] RouteSystem - Aviasales: запрос s9819291 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:21,410 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9819291&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:21,413 [INFO] RouteSystem - Aviasales: запрос s9819292 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:21,792 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9819292&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:21,794 [INFO] RouteSystem - Aviasales: запрос s9819293 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:22,169 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9819293&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:22,171 [INFO] RouteSystem - Aviasales: запрос s9819294 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:22,563 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9819294&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:22,567 [INFO] RouteSystem - Aviasales: запрос s9819295 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:22,946 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9819295&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:22,948 [INFO] RouteSystem - Aviasales: запрос s9819397 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:23,360 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9819397&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:23,362 [INFO] RouteSystem - Aviasales: запрос s9821647 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:23,743 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9821647&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:23,745 [INFO] RouteSystem - Aviasales: запрос s9837725 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:24,124 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9837725&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:24,130 [INFO] RouteSystem - Aviasales: запрос s9837879 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:24,531 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9837879&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:24,533 [INFO] RouteSystem - Aviasales: запрос s9837940 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:24,944 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9837940&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:24,949 [INFO] RouteSystem - Aviasales: запрос s9838065 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:25,332 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9838065&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:25,334 [INFO] RouteSystem - Aviasales: запрос s9838066 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:25,714 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9838066&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:25,715 [INFO] RouteSystem - Aviasales: запрос s9838077 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:26,126 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9838077&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:26,129 [INFO] RouteSystem - Aviasales: запрос s9838078 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:27,504 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9838078&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:27,506 [INFO] RouteSystem - Aviasales: запрос s9838183 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:27,898 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9838183&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:27,901 [INFO] RouteSystem - Aviasales: запрос s9850590 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:28,262 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9850590&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:28,264 [INFO] RouteSystem - Aviasales: запрос s9859177 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:28,629 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9859177&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:28,631 [INFO] RouteSystem - Aviasales: запрос s9859178 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:29,275 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9859178&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:29,276 [INFO] RouteSystem - Aviasales: запрос s9867679 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:29,649 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9867679&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:29,650 [INFO] RouteSystem - Aviasales: запрос s9867680 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:31,331 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9867680&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:31,333 [INFO] RouteSystem - Aviasales: запрос s9867681 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:31,699 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9867681&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:31,699 [INFO] RouteSystem - Aviasales: запрос s9867682 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:32,068 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9867682&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:32,070 [INFO] RouteSystem - Aviasales: запрос s9872499 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:32,459 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9872499&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:32,461 [INFO] RouteSystem - Aviasales: запрос s9874097 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:32,823 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9874097&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:32,825 [INFO] RouteSystem - Aviasales: запрос s9874098 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:33,212 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9874098&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:33,214 [INFO] RouteSystem - Aviasales: запрос s9874099 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:33,599 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9874099&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:33,600 [INFO] RouteSystem - Aviasales: запрос s9874100 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:33,968 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9874100&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:33,970 [INFO] RouteSystem - Aviasales: запрос s9875438 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:34,356 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9875438&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:34,359 [INFO] RouteSystem - Aviasales: запрос s9875439 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:34,748 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9875439&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:34,750 [INFO] RouteSystem - Aviasales: запрос s9875440 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:35,150 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9875440&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:35,153 [INFO] RouteSystem - Aviasales: запрос s9875441 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:35,550 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9875441&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:35,553 [INFO] RouteSystem - Aviasales: запрос s9875442 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:35,996 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9875442&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:35,999 [INFO] RouteSystem - Aviasales: запрос s9875443 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:36,403 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9875443&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:36,406 [INFO] RouteSystem - Aviasales: запрос s9878650 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:36,978 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9878650&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:36,985 [INFO] RouteSystem - Aviasales: запрос s9880865 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:37,404 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9880865&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:37,410 [INFO] RouteSystem - Aviasales: запрос s9881827 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:37,791 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9881827&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:37,793 [INFO] RouteSystem - Aviasales: запрос s9881828 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:38,189 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9881828&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:38,196 [INFO] RouteSystem - Aviasales: запрос s9882594 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:38,584 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9882594&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:38,586 [INFO] RouteSystem - Aviasales: запрос s9882879 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:38,958 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9882879&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:38,961 [INFO] RouteSystem - Aviasales: запрос s9883284 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:39,374 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9883284&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:39,384 [INFO] RouteSystem - Aviasales: запрос s9885904 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:39,899 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9885904&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:39,903 [INFO] RouteSystem - Aviasales: запрос s9886030 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:40,372 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9886030&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:40,378 [INFO] RouteSystem - Aviasales: запрос s9886185 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:40,856 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9886185&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:40,860 [INFO] RouteSystem - Aviasales: запрос s9887953 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:42,024 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9887953&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# 2025-03-16 22:43:42,028 [INFO] RouteSystem - Aviasales: запрос s9888121 -> s9602494 на 2025-03-17
# 2025-03-16 22:43:42,370 [ERROR] RouteSystem - Aviasales: ошибка запроса маршрутов: 400 Client Error: Bad Request for url: https://api.travelpayouts.com/v2/prices/latest?origin=s9888121&destination=s9602494&departure_at=2025-03-17&one_way=true&currency=RUB&token=dbd789b8fa1dadd43c5376abdcba15a0&limit=10&sorting=price
# Маршруты по Aviasales не найдены.
# 2025-03-16 22:43:42,790 [INFO] RouteSystem - Сохранён JSON: combined_Колпино_Санкт-Петербург_2025-03-17.json
# 2025-03-16 22:43:42,979 [INFO] RouteSystem - Сохранён CSV: combined_Колпино_Санкт-Петербург_2025-03-17.csv
# 2025-03-16 22:43:42,981 [INFO] RouteSystem - Построение графа: найдено 658 сегментов
# 2025-03-16 22:43:42,982 [INFO] RouteSystem - Граф построен: узлов=3, рёбер=46
# === Найденные маршруты (до 10) ===
#    Маршрут_ID  Номер сегмента Код отправления Город отправления  \
# 0           1               1        s9602657           Колпино
#
#            Время отправления Код прибытия  \
# 0  2025-03-17T05:52:00+03:00     s9602494
#
#                         Город прибытия             Время прибытия  \
# 0  Санкт-Петербург (Московский вокзал)  2025-03-17T06:25:00+03:00
#
#    Остановок (суток) Время в пути Вид транспорта
# 0                  0    0ч 33м 0с       suburban
